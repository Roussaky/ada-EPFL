# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, HTML
import warnings
import folium
import json
warnings.filterwarnings('ignore')

# %% [markdown]
# First we load the data

# %%
panama_entity = pd.read_csv('./Data/panama_papers.nodes.entity.csv')

# %%
## Any duplicated row?
panama_entity[panama_entity.duplicated()==True].shape[0]
# no duplicate row

## Features:
panama_entity.columns

## Convert feature:'n.incorporation_date' to type date
panama_entity['n.incorporation_date'] = pd.to_datetime(panama_entity['n.incorporation_date'])
# this conversion is essential, it let us do sorting.

# %% [markdown]
# * **Dataset Size:**
#     - rows: 213634
#     - features: 18
#
#
#
# * **'labels(n)':** "Entity"
# * **'n.valid_until':** 'The Panama Papers data is current through 2015'
# * **'n.country_codes':** 159 countries'code (exp: HKG for Hong Kong)
# * **'n.countries':** 159 countries'fullname
# * **'n.node_id':** node'id
# * **'n.sourceID':** 'Panama Papers'
# * **'n.address':** 18602 adress
# * **'n.name':** 206525 names
# * **'n.jurisdiction_description':** 21 jurisdictions'name

# %%
panama_entity['n.jurisdiction_description'].unique()
# Out:
# array(['Samoa', 'Panama', 'Nevada', 'United Kingdom', 'Singapore',
#        'Ras Al Khaimah', 'Isle Of Man', 'British Anguilla', 'Seychelles',
#        'Niue', 'Uruguay', 'British Virgin Islands', 'Hong Kong',
#        'New Zealand', 'Bahamas', 'Cyprus', 'Malta', 'Belize', 'Jersey',
#        'Wyoming', 'Costa Rica'], dtype=object)

# %% [markdown]
# * **'n.service_provider':** 'Mossack Fonseca'
# * **'n.jurisdiction':** 21 jurisdictions'code
# * **'n.closed_date':** NaN
# * **'n.incorporation_date':** 9493 incorporation'date between ['1936','2015']
# * **'n.ibcRUC':** 120046
# * **'n.type':** NaN
# * **'n.status':** Status
# * **'n.company_type':** NaN
# * **'n.note':** Notes

# %% [markdown]
# We make some plot to help us understand the data.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,12))


countries = pd.DataFrame(panama_entity['n.countries'].value_counts())
countries[:20].plot(kind='bar',title='Top 20 coutries most present in the dataset',ax=axes[0,0])
plt.ylabel('Number of entity')

jurisdiction = pd.DataFrame(panama_entity['n.jurisdiction_description'].value_counts())
jurisdiction[:10].plot(kind='bar',title='Top 10 jurisdiction most present in the dataset',ax=axes[0,1])
plt.ylabel('Number of entity')

status = pd.DataFrame(panama_entity['n.status'].value_counts())
status[:10].plot(kind='bar',title='Top 10 status most present in the dataset',ax=axes[1,0])
plt.ylabel('Number of entity')

names = pd.DataFrame(panama_entity['n.name'].value_counts())
names[:10].plot(kind='bar',title='Top 10 names most present in the dataset',ax=axes[1,1])
plt.ylabel('Number of entity')

plt.tight_layout()

plt.show()

# %%
year = pd.DataFrame(panama_entity['n.incorporation_date'].dropna().dt.year.astype(int).value_counts())
plt.figure(figsize=(10,5))
plt.plot(year['n.incorporation_date'].sort_index())
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# As we can see the curve are sensitives to some historical events. Let's try to understand which one.

# %% [markdown]
# # 1935 - 1960 Before the financial secrecy

# %% [markdown]
# The coutry hadn't have almost any offshore's entites

# %%
plt.figure(figsize=(10,5))
plt.plot(year['n.incorporation_date'].sort_index()[:10])
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# # 1960-2000 The beginning of corporate and individual financial secrecy
# The small decrease is due to the american invasion of the US invasion of panama

# %%
plt.figure(figsize=(10,5))
plt.plot(year['n.incorporation_date'].sort_index()[10:49])
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# # 2000-2005 The OECD report effect on Panama
# On 2000 the panama is black listed by the OECD as a fiscal paradise. The effect of this listing is immediate and we saw a decrease of the account. The same effect appears in 2002 when the Panama the 2002 OECD Model Agreement on Exchange of Information on Tax Matters is written and published. The investments rise after probably because entities has found a way to break this rules. In 2004, this report has been incorporated in the UN Model Tax Convention, an other decrease occurs.

# %%
plt.figure(figsize=(10,5))
plt.plot(year['n.incorporation_date'].sort_index()[46:55])
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# # The subprime crisis
# The crisis has a terrrible effect on the Panama and 4000 entity left the country

# %%
plt.figure(figsize=(10,5))
plt.plot(year['n.incorporation_date'].sort_index()[55:60])
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# # The after crisis and the Panama Paper's crisis
# The number of entities continue to decrease and in 2015 the Panama papers are leaked and the world discovered it.

# %%
plt.figure(figsize=(10,5))
plt.plot(year['n.incorporation_date'].sort_index()[60:])
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# ** At year 2005, there was almost 13246 entities but something happened which decreased number of entities after this year  **

# %%
evolution_feature_year = panama_entity[['n.incorporation_date','n.countries','n.jurisdiction_description','n.status']]
evolution_feature_year.dropna(subset = ['n.incorporation_date'], inplace=True)
evolution_feature_year['n.incorporation_date'] = evolution_feature_year['n.incorporation_date'].dt.year.astype(int)
evolution_feature_year['count'] = 1

# %%
top5_countries = countries[:5].index.tolist()
countries_year = evolution_feature_year[evolution_feature_year['n.countries'].isin(top5_countries)][['n.incorporation_date','n.countries','count']]
countries_year = countries_year.groupby(['n.incorporation_date','n.countries']).count().reset_index()

plt.figure(figsize=(10,5))
for country in top5_countries:
    data = countries_year[countries_year['n.countries']==country]
    data = data[data['n.incorporation_date']>=1975]
    plt.plot(data['n.incorporation_date'],data['count'])

plt.legend(top5_countries)
plt.xlabel('year')
plt.ylabel('number of entities')
plt.title('Evolution of number of Entities for each country')
plt.show()

# %%
top5_jurisdiction = jurisdiction[:5].index.tolist()
jurisdiction_year = evolution_feature_year[evolution_feature_year['n.jurisdiction_description'].isin(top5_jurisdiction)][['n.incorporation_date','n.jurisdiction_description','count']]
jurisdiction_year = jurisdiction_year.groupby(['n.incorporation_date','n.jurisdiction_description']).count().reset_index()

plt.figure(figsize=(10,5))
for jd in top5_jurisdiction:
    data = jurisdiction_year[jurisdiction_year['n.jurisdiction_description']==jd]
    data = data[data['n.incorporation_date']>=1975]
    plt.plot(data['n.incorporation_date'],data['count'])

plt.legend(top5_jurisdiction)
plt.xlabel('year')
plt.ylabel('number of entities')
plt.title('Evolution of number of Entities for each jurisdiction')
plt.show()

# %%
top5_status = status[:5].index.tolist()
status_year = evolution_feature_year[evolution_feature_year['n.status'].isin(top5_status)][['n.incorporation_date','n.status','count']]
status_year = status_year.groupby(['n.incorporation_date','n.status']).count().reset_index()

plt.figure(figsize=(10,5))
for st in top5_status:
    data = status_year[status_year['n.status']==st]
    data = data[data['n.incorporation_date']>=1975]
    plt.plot(data['n.incorporation_date'],data['count'])

plt.legend(top5_status)
plt.xlabel('year')
plt.ylabel('number of entities')
plt.title('Evolution of number of Entities for each status')
plt.show()

# %%
world_geo_path = './data/map.json'

with open(world_geo_path) as json_file:
    json_data = json.load(json_file)
countries_geo = pd.DataFrame(json_data) 
countries_geo['x'] = (countries_geo['north'].astype(float) + countries_geo['south'].astype(float)) /2
countries_geo['y'] = (countries_geo['east'].astype(float) + countries_geo['west'].astype(float)) /2
countries_geo = countries_geo[['country','x','y']]
countries_geo.set_index('country',inplace=True)

# %%
world_map = folium.Map([20,0], tiles='cartodbpositron', zoom_start=2)


entity_by_country = pd.DataFrame(panama_entity['n.countries'].value_counts())
entity_by_country.reset_index(inplace=True)
entity_by_country.columns = ['Country','count']
entity_by_country = entity_by_country[:30]

for i in range(0,len(entity_by_country)):
    country = entity_by_country.iloc[i]['Country']
    folium.CircleMarker(
      location=[countries_geo.ix[country]['x'], countries_geo.ix[country]['y']],
      popup=country+": "+str(entity_by_country.iloc[i]['count'])+" Entities",
      radius= entity_by_country.iloc[i]['count'].astype(float)/1000,
      color='blue',
      fill=True,
      fill_color='blue'
        
   ).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Officer

# %%
panama_officer = pd.read_csv('./Data/panama_papers.nodes.officer.csv')

# %%
# no duplicated row
panama_officer[panama_officer.duplicated()==True].shape[0]
# Out:
# 0

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,7))


countries = pd.DataFrame(panama_officer['n.countries'].value_counts())
countries[:20].plot(kind='bar',title='Top 20 coutries most present in the dataset',ax=axes[0])
plt.ylabel('Number of entity')

names = pd.DataFrame(panama_officer['n.name'].value_counts())
names[:10].plot(kind='bar',title='Top 10 names most present in the dataset',ax=axes[1])
plt.ylabel('Number of entity')

plt.tight_layout()

plt.show()

# %% [markdown]
# **The second plot is showing something weird with names "BEARER" & "EL PORTADOR" which lead us to some interresting facts...**

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15,5), squeeze=False)

names = pd.DataFrame(panama_officer[panama_officer['n.name'].str.contains('bearer|EL PORTADOR', case=False) == False ]['n.name'].value_counts())
names[:40].plot(kind='bar',title='Top 10 names most present in the dataset',ax=axes[0,0])
plt.ylabel('Number of entity')

plt.show()

# %%
pd.DataFrame(panama_officer[panama_officer['n.name'].str.contains('bearer', case=False) == True ]['n.name'].unique(),columns=['Names']).head()
# Out:
#                          Names
# 0                   THE BEARER
# 1  THE BEARER (MR. PAUL SPECK)
# 2            THE BEARER (EURO)
# 3                       BEARER
# 4                   the bearer

# %%
world_map = folium.Map([20,0], tiles='cartodbpositron', zoom_start=2)


world_geo_path = r'./data/world_map.geojson'

officer_by_country = pd.DataFrame(panama_officer['n.countries'].value_counts())
officer_by_country.reset_index(inplace=True)
officer_by_country.columns = ['Country','count']

world_map.choropleth(geo_data=world_geo_path, data=officer_by_country,
             columns=['Country','count'],
             key_on='feature.properties.name',
             fill_color='OrRd', fill_opacity=0.7, line_opacity=0.5,
             highlight=True,
             legend_name='Number of Officer')
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Intermediary

# %%
panama_intermediary = pd.read_csv('./Data/panama_papers.nodes.intermediary.csv')

# %%
# no duplicated row
panama_intermediary[panama_intermediary.duplicated()==True].shape[0]
# Out:
# 0

# %%
panama_intermediary.shape
# Out:
# (14110, 18)

# %%
panama_intermediary.head(n=2)
# Out:
#           labels(n)                                    n.valid_until  \
# 0  ["Intermediary"]  The Panama Papers  data is current through 2015
# 1  ["Intermediary"]  The Panama Papers  data is current through 2015
#
#   n.country_codes    n.countries  n.node_id     n.sourceID  \
# 0             ZAF   South Africa   11000001  Panama Papers
# 1             LIE  Liechtenstein   11000002  Panama Papers
#
#                                            n.address                   n.name  \
# 0  MICHAEL PAPAGEORGE; MR. 106 NICHOLSON STREET B...  MICHAEL PAPAGEORGE, MR.
# 1                                                NaN       CORFIDUCIA ANSTALT
#
#    n.jurisdiction_description  n.service_provider  n.jurisdiction  \
# 0                         NaN                 NaN             NaN
# 1                         NaN                 NaN             NaN
#
#    n.closed_date  n.incorporation_date  n.ibcRUC  n.type n.status  \
# 0            NaN                   NaN       NaN     NaN   ACTIVE
# 1            NaN                   NaN       NaN     NaN   ACTIVE
#
#    n.company_type n.note
# 0             NaN    NaN
# 1             NaN    NaN

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))


countries = pd.DataFrame(panama_intermediary['n.countries'].value_counts())
countries[:10].plot(kind='bar',title='Top 20 coutries most present in the dataset',ax=axes[0])
plt.ylabel('Number of entity')

status = pd.DataFrame(panama_intermediary['n.status'].value_counts())
status[:5].plot(kind='bar',title='Top 10 status most present in the dataset',ax=axes[1])
plt.ylabel('Number of entity')

plt.tight_layout()

plt.show()

# %%
names = pd.DataFrame(panama_intermediary['n.name'].value_counts())
names[:4]
# Out:
#                                n.name
# WILDGEN & PARTNERS                  2
# COMPANHIA DE NAVEGAÇÃO NORSUL       2
# FERNANDEZ G., JUAN ANTONIO          2
# ENRIQUE O. GRISANTI                 2

# %%
geo_data = countries.reset_index()
geo_data.columns =['Country','count']
geo_data = geo_data[~geo_data['Country'].str.contains(';')]
geo_data = geo_data[:50]

# %%
world_geo_path = './data/map.json'

with open(world_geo_path) as json_file:
    json_data = json.load(json_file)
countries_geo = pd.DataFrame(json_data) 
countries_geo['x'] = (countries_geo['north'].astype(float) + countries_geo['south'].astype(float)) /2
countries_geo['y'] = (countries_geo['east'].astype(float) + countries_geo['west'].astype(float)) /2
countries_geo = countries_geo[['country','x','y']]
countries_geo.set_index('country',inplace=True)

# %%
world_map = folium.Map([20,0], tiles='cartodbpositron', zoom_start=2)

for i in range(0,len(geo_data)):
    country = geo_data.iloc[i]['Country']
    folium.CircleMarker(
      location=[countries_geo.ix[country]['x'], countries_geo.ix[country]['y']],
      popup=country+": "+str(geo_data.iloc[i]['count']),
      radius= geo_data.iloc[i]['count'].astype(float)/50,
      color='crimson',
      fill=True,
      fill_color='crimson'
        
   ).add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adress

# %%
panama_adress = pd.read_csv('./Data/panama_papers.nodes.address.csv')

# %%
# no duplicated row
panama_adress[panama_adress.duplicated()==True].shape[0]
# Out:
# 0

# %%
panama_adress.shape
# Out:
# (93454, 18)

# %%
panama_adress.head(n=2)
# Out:
#      labels(n)                                    n.valid_until  \
# 0  ["Address"]  The Panama Papers  data is current through 2015
# 1  ["Address"]  The Panama Papers  data is current through 2015
#
#   n.country_codes n.countries  n.node_id     n.sourceID  \
# 0             SGP   Singapore   14000001  Panama Papers
# 1             KAZ  Kazakhstan   14000002  Panama Papers
#
#                                       n.address  n.name  \
# 0  -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920     NaN
# 1       "Almaly Village" v.5, Almaty Kazakhstan     NaN
#
#    n.jurisdiction_description  n.service_provider  n.jurisdiction  \
# 0                         NaN                 NaN             NaN
# 1                         NaN                 NaN             NaN
#
#    n.closed_date  n.incorporation_date  n.ibcRUC  n.type  n.status  \
# 0            NaN                   NaN       NaN     NaN       NaN
# 1            NaN                   NaN       NaN     NaN       NaN
#
#    n.company_type  n.note
# 0             NaN     NaN
# 1             NaN     NaN

# %% [markdown]
# ## Edges

# %%
panama_edges = pd.read_csv('./Data/panama_papers.edges.csv')

# %%
## Duplicated row: 8
panama_edges.drop(panama_edges[panama_edges.duplicated()==True].index,inplace=True)

# %% [markdown]
# * **Dataset Size:**
#     * relations: 674094
#     * features: 7
#
#
# * ** 'node_1':**  nodeId 1
# * ** 'node_2':** nodeId 2
# * ** 'r.sourceID':** Panama Papers
# * ** 'r.valid_until':** The Panama Papers data is current through 2015
# * **'rel_type': **relation type

# %%
panama_edges['rel_type'].unique()
# Out:
# array(['registered_address', 'intermediary_of', 'officer_of'], dtype=object)

# %%
panama_edges.head()
# Out:
#      node_1            rel_type    node_2     r.sourceID r.valid_until  \
# 0  10000035  registered_address  14095990  Panama Papers           NaN
# 1  10000044  registered_address  14091035  Panama Papers           NaN
# 2  10000055  registered_address  14095990  Panama Papers           NaN
# 3  10000064  registered_address  14091429  Panama Papers           NaN
# 4  10000089  registered_address  14098253  Panama Papers           NaN
#
#   r.start_date r.end_date
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN

# %%
weird_date  = panama_edges['r.start_date'].dropna().apply(lambda x: x.split('-')[2]).astype(int) < 1900
index_weird_date = weird_date [weird_date  == True].index
panama_edges.ix[index_weird_date].head()
# Out:
#           node_1    rel_type    node_2     r.sourceID  \
# 228844  12010651  officer_of  10034573  Panama Papers
# 229514  12011199  officer_of  10034573  Panama Papers
# 232296  12013401  officer_of  10180308  Panama Papers
# 239696  12019679  officer_of  10026442  Panama Papers
# 246608  12025977  officer_of  10192685  Panama Papers
#
#                                          r.valid_until r.start_date  \
# 228844  The Panama Papers data is current through 2015  18-JUN-0082
# 229514  The Panama Papers data is current through 2015  18-JUN-0082
# 232296  The Panama Papers data is current through 2015  04-JAN-0200
# 239696  The Panama Papers data is current through 2015  28-OCT-0200
# 246608  The Panama Papers data is current through 2015  27-MAY-0202
#
#          r.end_date
# 228844  07-APR-2005
# 229514  07-APR-2005
# 232296  25-JUN-2001
# 239696          NaN
# 246608  28-SEP-2010

# %%
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0012','2012')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0014','2014')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0003','2003')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0082','1982')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0200','2000')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0202','2002')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0203','2003')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2500','2005')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('1194','1994')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0199','1999')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0015','2015')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0009','2009')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0006','2006')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0201','2001')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0095','1995')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0004','2004')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0213','2013')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0096','1996')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0214','2014')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0011','2011')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('0206','2006')

# We also checked the incoherence between start_date and end_date,
#for exp: 'r.start_date': 18-MAR-2019 & 'r.end_date': 06-OCT-2009 
#         means that start_date was probably in year 2009 instead of 2019
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2088','2008')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2019','2009')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2020','2002')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2099','2009')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2201','2001')
panama_edges['r.start_date']  = panama_edges['r.start_date'].str.replace('2205','2005')

# %%
weird_date  = panama_edges['r.end_date'].dropna().apply(lambda x: x.split('-')[2]).astype(int) < 1900
index_weird_date = weird_date [weird_date  == True].index
panama_edges.ix[index_weird_date].head()
# Out:
#           node_1    rel_type    node_2     r.sourceID  \
# 271446  12048615  officer_of  10150924  Panama Papers
# 271447  12048616  officer_of  10150924  Panama Papers
# 271467  12048617  officer_of  10150924  Panama Papers
# 271468  12048618  officer_of  10150924  Panama Papers
# 271469  12048619  officer_of  10150924  Panama Papers
#
#                                          r.valid_until r.start_date  \
# 271446  The Panama Papers data is current through 2015  11-JUN-2002
# 271447  The Panama Papers data is current through 2015  11-JUN-2002
# 271467  The Panama Papers data is current through 2015  11-JUN-2002
# 271468  The Panama Papers data is current through 2015  11-JUN-2002
# 271469  The Panama Papers data is current through 2015  11-JUN-2002
#
#          r.end_date
# 271446  06-NOV-0009
# 271447  06-NOV-0009
# 271467  06-NOV-0009
# 271468  06-NOV-0009
# 271469  06-NOV-0009

# %%
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0213','2013')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0206','2006')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0012','2012')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0200','2000')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0201','2001')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0015','2015')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0199','1999')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0208','2008')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0006','2006')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0009','2009')
panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('0213','2013')

panama_edges['r.end_date']  = panama_edges['r.end_date'].str.replace('2209','2009')

# %%
## Convert feature:'r.start_date' & 'r.end_date' to type date
panama_edges['r.start_date'] = pd.to_datetime(panama_edges['r.start_date'])
panama_edges['r.end_date'] = pd.to_datetime(panama_edges['r.end_date'])

# %% [markdown]
#    * ** 'r.star_date':** years between ['1957','2015']
#    * ** 'r.end_date':** years beatween ['1959','2020']

# %% [markdown]
# # Address registration of Entities

# %%
registered_address = panama_edges[panama_edges['rel_type'] == 'registered_address' ]

# %%
#select entities node_id range
entity_address = registered_address[registered_address['node_1']<11000000]
dict_entity_address = entity_address[['node_1','node_2']].groupby('node_2')['node_1'].apply(lambda x: x.tolist()).to_dict()
famous_adress = sorted(dict_entity_address, key=lambda k: len(dict_entity_address[k]), reverse=True)
number_of_entities = list(map(len,list(map(dict_entity_address.get,famous_adress))))

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15,5), squeeze=False)

entity_address_count = pd.DataFrame({'address_id':famous_adress,'number_of_entities':number_of_entities})
entity_address_count.set_index(['address_id'],inplace=True)
entity_address_count[:40].plot(kind='bar',title='Top 40 most used address for entities',ax=axes[0,0])
plt.show()

# %%
panama_adress[panama_adress['n.node_id'].isin(entity_address_count[:2].index.tolist())]['n.address']
# Out:
# 91248    CONSULTORES LEGALES; S. A. EDIFICIO PLAZA CORP...
# 91536    ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...
# Name: n.address, dtype: object

# %% [markdown]
# * ** This address located in 'Guatemala'& 'Switzerland' register around 44 entities each!! **
#
# * ** Let's see those 44 entities located in Switzerland: ** ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...

# %%
entities_44 = panama_entity[panama_entity['n.node_id'].isin(dict_entity_address[famous_adress[1]])]
entities_44.head()
# Out:
#          labels(n)                                   n.valid_until  \
# 55162   ["Entity"]  The Panama Papers data is current through 2015
# 59771   ["Entity"]  The Panama Papers data is current through 2015
# 69195   ["Entity"]  The Panama Papers data is current through 2015
# 97921   ["Entity"]  The Panama Papers data is current through 2015
# 121994  ["Entity"]  The Panama Papers data is current through 2015
#
#        n.country_codes  n.countries  n.node_id     n.sourceID  \
# 55162              CHE  Switzerland   10055798  Panama Papers
# 59771              CHE  Switzerland   10059898  Panama Papers
# 69195              CHE  Switzerland   10068722  Panama Papers
# 97921              CHE  Switzerland   10096390  Panama Papers
# 121994             CHE  Switzerland   10156808  Panama Papers
#
#                                                 n.address  \
# 55162   ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...
# 59771   ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...
# 69195   ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...
# 97921   ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...
# 121994  ETUDE DE MES REYMOND; ULMANN & FISCHELE (CHRIS...
#
#                                          n.name n.jurisdiction_description  \
# 55162                     HASSIFA TRADING CORP.                     Panama
# 59771                       DIFESA TRADING LTD.     British Virgin Islands
# 69195   CONSULTING, TRADING & INVESTING LIMITED     British Virgin Islands
# 97921                       REYDEL FINANCE LTD.     British Virgin Islands
# 121994                        Riversource Corp.                     Panama
#
#        n.service_provider n.jurisdiction  n.closed_date n.incorporation_date  \
# 55162     Mossack Fonseca            PMA            NaN           2008-08-29
# 59771     Mossack Fonseca            BVI            NaN           1993-07-23
# 69195     Mossack Fonseca            BVI            NaN           1996-04-30
# 97921     Mossack Fonseca            BVI            NaN           2002-01-02
# 121994    Mossack Fonseca            PMA            NaN           2011-09-29
#
#        n.ibcRUC  n.type   n.status  n.company_type n.note
# 55162        29     NaN     Active             NaN    NaN
# 59771     91640     NaN  Defaulted             NaN    NaN
# 69195    184016     NaN  Dissolved             NaN    NaN
# 97921    475047     NaN  Defaulted             NaN    NaN
# 121994       86     NaN     Active             NaN    NaN

# %% [markdown]
# * All of them are provided by ** Mossack Fonseca **
# * Jurisdiction:
#     * **Panama:** 36
#     * **British Virgin Islands:** 8

# %%
#pd.DataFrame(entities_44['n.incorporation_date'].sort_values()).set_index('n.incorporation_date').ix['2011-01-01':'2013-12-01']

# %%
plt.figure(figsize=(10,5))
plt.plot(entities_44['n.incorporation_date'].dt.year.astype(int).value_counts().sort_index())
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year')
plt.show()

# %% [markdown]
# * Just in 2011, 18 entities was registred in the same address by Mossack Fonseca:
#     * **07/2011:** 4 entities registrations
#     * **12/2011:** 5 entities registrations

# %%
entities_44['n.name'].head()
# Out:
# 55162                       HASSIFA TRADING CORP.
# 59771                         DIFESA TRADING LTD.
# 69195     CONSULTING, TRADING & INVESTING LIMITED
# 97921                         REYDEL FINANCE LTD.
# 121994                          Riversource Corp.
# Name: n.name, dtype: object

# %% [markdown]
# * Most of this entities are for **Trading, Finance or Consulting**

# %% [markdown]
# * For Interractive Viz of this node please visit this link: https://offshoreleaks.icij.org/nodes/11011617

# %% [markdown]
# # Merging all data

# %%
panama_nodes = pd.concat([panama_entity,panama_intermediary,panama_officer,panama_adress])
panama_nodes.to_csv('./Data/merged_data.csv')

# %%
panama_nodes.head(n=50)
# Out:
#      labels(n)                                   n.valid_until  \
# 0   ["Entity"]  The Panama Papers data is current through 2015
# 1   ["Entity"]  The Panama Papers data is current through 2015
# 2   ["Entity"]  The Panama Papers data is current through 2015
# 3   ["Entity"]  The Panama Papers data is current through 2015
# 4   ["Entity"]  The Panama Papers data is current through 2015
# 5   ["Entity"]  The Panama Papers data is current through 2015
# 6   ["Entity"]  The Panama Papers data is current through 2015
# 7   ["Entity"]  The Panama Papers data is current through 2015
# 8   ["Entity"]  The Panama Papers data is current through 2015
# 9   ["Entity"]  The Panama Papers data is current through 2015
# 10  ["Entity"]  The Panama Papers data is current through 2015
# 11  ["Entity"]  The Panama Papers data is current through 2015
# 12  ["Entity"]  The Panama Papers data is current through 2015
# 13  ["Entity"]  The Panama Papers data is current through 2015
# 14  ["Entity"]  The Panama Papers data is current through 2015
# 15  ["Entity"]  The Panama Papers data is current through 2015
# 16  ["Entity"]  The Panama Papers data is current through 2015
# 17  ["Entity"]  The Panama Papers data is current through 2015
# 18  ["Entity"]  The Panama Papers data is current through 2015
# 19  ["Entity"]  The Panama Papers data is current through 2015
# 20  ["Entity"]  The Panama Papers data is current through 2015
# 21  ["Entity"]  The Panama Papers data is current through 2015
# 22  ["Entity"]  The Panama Papers data is current through 2015
# 23  ["Entity"]  The Panama Papers data is current through 2015
# 24  ["Entity"]  The Panama Papers data is current through 2015
# 25  ["Entity"]  The Panama Papers data is current through 2015
# 26  ["Entity"]  The Panama Papers data is current through 2015
# 27  ["Entity"]  The Panama Papers data is current through 2015
# 28  ["Entity"]  The Panama Papers data is current through 2015
# 29  ["Entity"]  The Panama Papers data is current through 2015
# 30  ["Entity"]  The Panama Papers data is current through 2015
# 31  ["Entity"]  The Panama Papers data is current through 2015
# 32  ["Entity"]  The Panama Papers data is current through 2015
# 33  ["Entity"]  The Panama Papers data is current through 2015
# 34  ["Entity"]  The Panama Papers data is current through 2015
# 35  ["Entity"]  The Panama Papers data is current through 2015
# 36  ["Entity"]  The Panama Papers data is current through 2015
# 37  ["Entity"]  The Panama Papers data is current through 2015
# 38  ["Entity"]  The Panama Papers data is current through 2015
# 39  ["Entity"]  The Panama Papers data is current through 2015
# 40  ["Entity"]  The Panama Papers data is current through 2015
# 41  ["Entity"]  The Panama Papers data is current through 2015
# 42  ["Entity"]  The Panama Papers data is current through 2015
# 43  ["Entity"]  The Panama Papers data is current through 2015
# 44  ["Entity"]  The Panama Papers data is current through 2015
# 45  ["Entity"]  The Panama Papers data is current through 2015
# 46  ["Entity"]  The Panama Papers data is current through 2015
# 47  ["Entity"]  The Panama Papers data is current through 2015
# 48  ["Entity"]  The Panama Papers data is current through 2015
# 49  ["Entity"]  The Panama Papers data is current through 2015
#
#    n.country_codes    n.countries  n.node_id     n.sourceID  \
# 0              HKG      Hong Kong   10000001  Panama Papers
# 1              HKG      Hong Kong   10000002  Panama Papers
# 2              HKG      Hong Kong   10000003  Panama Papers
# 3              HKG      Hong Kong   10000004  Panama Papers
# 4              HKG      Hong Kong   10000005  Panama Papers
# 5              HKG      Hong Kong   10000006  Panama Papers
# 6              HKG      Hong Kong   10000007  Panama Papers
# 7              HKG      Hong Kong   10000008  Panama Papers
# 8              HKG      Hong Kong   10000009  Panama Papers
# 9              HKG      Hong Kong   10000010  Panama Papers
# 10             HKG      Hong Kong   10000011  Panama Papers
# 11             HKG      Hong Kong   10000012  Panama Papers
# 12             TWN         Taiwan   10000013  Panama Papers
# 13             CHN          China   10000014  Panama Papers
# 14             HKG      Hong Kong   10000015  Panama Papers
# 15             HKG      Hong Kong   10000019  Panama Papers
# 16             HKG      Hong Kong   10000020  Panama Papers
# 17             CHN          China   10000021  Panama Papers
# 18             CHE    Switzerland   10000024  Panama Papers
# 19             HKG      Hong Kong   10000016  Panama Papers
# 20             SGP      Singapore   10000017  Panama Papers
# 21             TWN         Taiwan   10000018  Panama Papers
# 22             TWN         Taiwan   10000022  Panama Papers
# 23             TWN         Taiwan   10000023  Panama Papers
# 24             CHE    Switzerland   10000025  Panama Papers
# 25             CHE    Switzerland   10000026  Panama Papers
# 26             BRA         Brazil   10000027  Panama Papers
# 27             CHE    Switzerland   10000028  Panama Papers
# 28             HKG      Hong Kong   10000029  Panama Papers
# 29             TWN         Taiwan   10000030  Panama Papers
# 30             TWN         Taiwan   10000031  Panama Papers
# 31             SGP      Singapore   10000032  Panama Papers
# 32             PAN         Panama   10000033  Panama Papers
# 33             WSM          Samoa   10000034  Panama Papers
# 34             CHE    Switzerland   10000035  Panama Papers
# 35             CHE    Switzerland   10000036  Panama Papers
# 36             PAN         Panama   10000037  Panama Papers
# 37             PAN         Panama   10000038  Panama Papers
# 38             CHE    Switzerland   10000059  Panama Papers
# 39             HKG      Hong Kong   10000039  Panama Papers
# 40             HKG      Hong Kong   10000040  Panama Papers
# 41             LIE  Liechtenstein   10000041  Panama Papers
# 42             CHE    Switzerland   10000042  Panama Papers
# 43             CHE    Switzerland   10000043  Panama Papers
# 44             HKG      Hong Kong   10000044  Panama Papers
# 45             TWN         Taiwan   10000045  Panama Papers
# 46             HKG      Hong Kong   10000046  Panama Papers
# 47             HKG      Hong Kong   10000047  Panama Papers
# 48             HKG      Hong Kong   10000048  Panama Papers
# 49             HKG      Hong Kong   10000049  Panama Papers
#
#                                             n.address  \
# 0   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 1   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 2   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 3   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 4   LOYAL PORT LIMITED 8/F; CRAWFORD TOWER 99 JERV...
# 5   TWC MANAGEMENT LIMITED SUITE D; 19/F RITZ PLAZ...
# 6   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 7   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 8   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 9   ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 10  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 11  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 12  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 13  AFOR LAW FIRM, SICHUAN CHENGDU SHUANGNAN PIK W...
# 14  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 15  TWC MANAGEMENT LIMITED SUITE D; 19/F RITZ PLAZ...
# 16  MEI SERVICES LIMITED ROOM E; 6TH FLOOR; EASTER...
# 17  AFOR LAW FIRM, SICHUAN CHENGDU SHUANGNAN PIK W...
# 18  FCI LTD. ATT.: MR. DAVID RISBEY POSTFACH 24 72...
# 19  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 20  MOSSACK FONSECA & CO. (SINGAPORE) PTE LTD.  19...
# 21  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 22  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 23  DI SAN DI MANAGEMENT COMPANY LIMITED 7F- 4; NO...
# 24  MR. SPYRO A. METAXAS RUE DE HESSE 16 CASE POST...
# 25  MR. SPYRO A. METAXAS RUE DE HESSE 16 CASE POST...
# 26  MIGUEL NETO ADVOGADOS RUA GUARARAPES; 1909 CON...
# 27  MSG S.A. 5, CH. DE LA VUACHÈRE CASE POSTALE 10...
# 28  WILLIE MANAGEMENT LIMITED 12TH FLOOR; LUCKY BU...
# 29  SINO-WEST INTERNATIONAL CO.; LTD. 3F-6; NO. 36...
# 30  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 31  MOSSACK FONSECA & CO. (SINGAPORE) PTE LTD.  19...
# 32  MOSSACK FONSECA & CO. MOSSFON BUILDING CALLE 5...
# 33  MOSSACK FONSECA & CO. CZECH INC. LEVEL 5; DEVE...
# 34  EUROFIN SERVICES S.A. P.O.BOX  6003 LAUSANNE 1...
# 35  GESTAR S.A. AVENUE DE MONTCHOISI 35 CASE POSTA...
# 36  MOSSACK FONSECA & CO. MOSSFON BUILDING CALLE 5...
# 37  MOSSACK FONSECA & CO. MOSSFON BUILDING CALLE 5...
# 38  LIC. ANDRE ZOLTY 8C; AVENUE DE CHAMPEL  1206; ...
# 39  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 40  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 41  AUDINA TREUHAND AG LANDSTRASSE 37 9490 VADUZ L...
# 42  MSG S.A. CHEMIN DE VUACHÈRE  5 CASE POSTALE 10...
# 43  FORVEST TRUST S.A. 14; RUE KLEBERG CASE POSTAL...
# 44  AKMJ CONSULTING SERVICES LIMITED 20/F.; BANGKO...
# 45  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 46  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 47  MEI SERVICES LIMITED ROOM E; 6TH FLOOR; EASTER...
# 48  PERFECT COMPANY 2/F.; 114 TO KWA WAN ROAD; KOW...
# 49  GLOBAL STAR CONSULTANTS LIMITED ROOM 1120; 11/...
#
#                                           n.name n.jurisdiction_description  \
# 0       TIANSHENG INDUSTRY AND TRADING CO., LTD.                      Samoa
# 1    NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.                      Samoa
# 2                             HOTFOCUS CO., LTD.                      Samoa
# 3                SKY-BLUE GIFTS & TOYS CO., LTD.                      Samoa
# 4           FORTUNEMAKER INVESTMENTS CORPORATION                      Samoa
# 5                           8808 HOLDING LIMITED                      Samoa
# 6                       KENT DEVELOPMENT LIMITED                      Samoa
# 7                            BONUS TRADE LIMITED                      Samoa
# 8                                 AMARANDAN LTD.                      Samoa
# 9                               NEW IDEA LIMITED                      Samoa
# 10                            HUGH POWER LIMITED                      Samoa
# 11                        ULTIMATE GROUP LIMITED                      Samoa
# 12                         VICTORY GROUP LIMITED                      Samoa
# 13                          CHARTER MARK LIMITED                      Samoa
# 14          Wide International Trading Co., Ltd.                      Samoa
# 15                       HTSS ET CAPITAL LIMITED                      Samoa
# 16                    JIE LUN INVESTMENT LIMITED                      Samoa
# 17                        FORTUNE PALACE LIMITED                      Samoa
# 18                  LAKE STREET INVESTMENTS LTD.                      Samoa
# 19  NINGBO RAPID INTERNATIONAL TRADING CO., LTD.                      Samoa
# 20                   ANGELIKA INTERNATIONAL LTD.                      Samoa
# 21                                CHEM D-T Corp.                      Samoa
# 22                  PRESTIGE INTERNATIONAL CORP.                      Samoa
# 23          SUNNY TREASURE INTERNATIONAL LIMITED                      Samoa
# 24                                   GIT CO INC.                      Samoa
# 25                  EURO INVESTMENT CAPITAL INC.                      Samoa
# 26                 WORLD TOOLS INVESTMENTS CORP.                      Samoa
# 27                            WINESELECTION S.A.                      Samoa
# 28                      NECY CONSULTANTS LIMITED                      Samoa
# 29                       KIND INTERNATIONAL INC.                      Samoa
# 30                            Aegis Infocom Inc.                      Samoa
# 31                   TOPLINE INVESTMENTS LIMITED                      Samoa
# 32                    CLARKSBURG MANAGEMENT LTD.                      Samoa
# 33                    Alvear Investments Limited                      Samoa
# 34                  CARPENTER NELSON & CO., LTD.                      Samoa
# 35                      RIVIERA HOLDINGS LIMITED                      Samoa
# 36                        PARKDALE HOLDINGS LTD.                      Samoa
# 37                       SADDLEVILLE CORPORATION                      Samoa
# 38                      TETRA INTERNATIONAL LTD.                      Samoa
# 39     BELLEVUE INTERNATIONAL (FRANCE) CO., LTD.                      Samoa
# 40                 MEIHO INTERNATIONAL CO., LTD.                      Samoa
# 41                              LONSDALE LIMITED                      Samoa
# 42                                GARIBALDI S.A.                      Samoa
# 43                    DAFORD INTERNATIONAL CORP.                      Samoa
# 44              GOLDEN NET INTERNATIONAL LIMITED                      Samoa
# 45                         EXCELLENCE GROUP LTD.                      Samoa
# 46                 D&C SUZHOU INTERNATIONAL LTD.                      Samoa
# 47                          CORAL SEA GROUP LTD.                      Samoa
# 48                         DELTORIA TRADING LTD.                      Samoa
# 49             AMPLE YIELD INTERNATIONAL LIMITED                      Samoa
#
#    n.service_provider n.jurisdiction  n.closed_date n.incorporation_date  \
# 0     Mossack Fonseca            SAM            NaN           2006-03-23
# 1     Mossack Fonseca            SAM            NaN           2006-03-27
# 2     Mossack Fonseca            SAM            NaN           2006-01-10
# 3     Mossack Fonseca            SAM            NaN           2006-01-06
# 4     Mossack Fonseca            SAM            NaN           2006-04-19
# 5     Mossack Fonseca            SAM            NaN           2006-01-05
# 6     Mossack Fonseca            SAM            NaN           2004-01-26
# 7     Mossack Fonseca            SAM            NaN           2004-02-13
# 8     Mossack Fonseca            SAM            NaN           2004-01-26
# 9     Mossack Fonseca            SAM            NaN           2004-03-30
# 10    Mossack Fonseca            SAM            NaN           2004-03-30
# 11    Mossack Fonseca            SAM            NaN           2004-04-05
# 12    Mossack Fonseca            SAM            NaN           2004-03-30
# 13    Mossack Fonseca            SAM            NaN           2004-02-13
# 14    Mossack Fonseca            SAM            NaN           2006-01-06
# 15    Mossack Fonseca            SAM            NaN           2006-08-21
# 16    Mossack Fonseca            SAM            NaN           2006-04-10
# 17    Mossack Fonseca            SAM            NaN           2004-03-29
# 18    Mossack Fonseca            SAM            NaN           2004-02-06
# 19    Mossack Fonseca            SAM            NaN           2006-01-12
# 20    Mossack Fonseca            SAM            NaN           2004-01-26
# 21    Mossack Fonseca            SAM            NaN           2004-03-30
# 22    Mossack Fonseca            SAM            NaN           2004-06-10
# 23    Mossack Fonseca            SAM            NaN           2004-02-06
# 24    Mossack Fonseca            SAM            NaN           2006-11-21
# 25    Mossack Fonseca            SAM            NaN           2006-10-27
# 26    Mossack Fonseca            SAM            NaN           2006-12-19
# 27    Mossack Fonseca            SAM            NaN           2006-12-29
# 28    Mossack Fonseca            SAM            NaN           2006-03-22
# 29    Mossack Fonseca            SAM            NaN           2006-09-07
# 30    Mossack Fonseca            SAM            NaN           2006-01-17
# 31    Mossack Fonseca            SAM            NaN           2006-08-28
# 32    Mossack Fonseca            SAM            NaN           2004-01-30
# 33    Mossack Fonseca            SAM            NaN           2004-03-12
# 34    Mossack Fonseca            SAM            NaN           2006-05-23
# 35    Mossack Fonseca            SAM            NaN           2006-06-07
# 36    Mossack Fonseca            SAM            NaN           2004-01-30
# 37    Mossack Fonseca            SAM            NaN           2004-01-30
# 38    Mossack Fonseca            SAM            NaN           2007-02-07
# 39    Mossack Fonseca            SAM            NaN           2006-01-23
# 40    Mossack Fonseca            SAM            NaN           2006-01-11
# 41    Mossack Fonseca            SAM            NaN           2006-09-08
# 42    Mossack Fonseca            SAM            NaN           2007-01-26
# 43    Mossack Fonseca            SAM            NaN           2006-10-27
# 44    Mossack Fonseca            SAM            NaN           2006-02-13
# 45    Mossack Fonseca            SAM            NaN           2006-01-05
# 46    Mossack Fonseca            SAM            NaN           2006-01-11
# 47    Mossack Fonseca            SAM            NaN           2006-04-10
# 48    Mossack Fonseca            SAM            NaN           2006-01-05
# 49    Mossack Fonseca            SAM            NaN           2006-12-19
#
#    n.ibcRUC  n.type                       n.status  n.company_type n.note
# 0     25221     NaN                      Defaulted             NaN    NaN
# 1     25249     NaN                      Defaulted             NaN    NaN
# 2     24138     NaN                      Defaulted             NaN    NaN
# 3     24012     NaN                      Defaulted             NaN    NaN
# 4    R25638     NaN                  Changed agent             NaN    NaN
# 5     23835     NaN                         Active             NaN    NaN
# 6     15757     NaN                      Defaulted             NaN    NaN
# 7     15910     NaN                      Defaulted             NaN    NaN
# 8     15759     NaN                      Defaulted             NaN    NaN
# 9     16462     NaN                      Defaulted             NaN    NaN
# 10    16464     NaN                      Defaulted             NaN    NaN
# 11    16573     NaN                         Active             NaN    NaN
# 12    16460     NaN                      Defaulted             NaN    NaN
# 13    15913     NaN                      Defaulted             NaN    NaN
# 14    24014     NaN                         Active             NaN    NaN
# 15    27502     NaN                      Defaulted             NaN    NaN
# 16    25475     NaN                         Active             NaN    NaN
# 17    16408     NaN                      Defaulted             NaN    NaN
# 18    15858     NaN                    Inactivated             NaN    NaN
# 19    24181     NaN                      Defaulted             NaN    NaN
# 20    15774     NaN                      Defaulted             NaN    NaN
# 21    16469     NaN                      Defaulted             NaN    NaN
# 22    17370     NaN                         Active             NaN    NaN
# 23    15857     NaN                      Defaulted             NaN    NaN
# 24   R28975     NaN                      Defaulted             NaN    NaN
# 25   R28631     NaN                      Defaulted             NaN    NaN
# 26   R29502     NaN  Relocated in new jurisdiction             NaN    NaN
# 27   R29714     NaN                      Defaulted             NaN    NaN
# 28   R25192     NaN                         Active             NaN    NaN
# 29   R27848     NaN                      Defaulted             NaN    NaN
# 30    24240     NaN                         Active             NaN    NaN
# 31   R27674     NaN                      Defaulted             NaN    NaN
# 32    15803     NaN        Dissolved shelf company             NaN    NaN
# 33    16228     NaN                      Defaulted             NaN    NaN
# 34   R26091     NaN                      Defaulted             NaN    NaN
# 35   R26388     NaN                      Defaulted             NaN    NaN
# 36    15798     NaN        Dissolved shelf company             NaN    NaN
# 37    15800     NaN        Dissolved shelf company             NaN    NaN
# 38   R30965     NaN                      Defaulted             NaN    NaN
# 39    24364     NaN                      Defaulted             NaN    NaN
# 40    24165     NaN                         Active             NaN    NaN
# 41    27876     NaN                      Defaulted             NaN    NaN
# 42   R30721     NaN                      Defaulted             NaN    NaN
# 43   R28628     NaN                      Defaulted             NaN    NaN
# 44   R24693     NaN                         Active             NaN    NaN
# 45    23841     NaN                      Defaulted             NaN    NaN
# 46    24166     NaN                         Active             NaN    NaN
# 47    25470     NaN                      Defaulted             NaN    NaN
# 48    23833     NaN                      Defaulted             NaN    NaN
# 49   R29498     NaN                      Defaulted             NaN    NaN

# %% [markdown]
# * **node_id** that start with/refere to:
#     * 10: Entity
#     * 11: Intermediary
#     * 12 & 15: Officer
#     * 14: Adress

# %%
panama_edges.head()
# Out:
#      node_1            rel_type    node_2     r.sourceID r.valid_until  \
# 0  10000035  registered_address  14095990  Panama Papers           NaN
# 1  10000044  registered_address  14091035  Panama Papers           NaN
# 2  10000055  registered_address  14095990  Panama Papers           NaN
# 3  10000064  registered_address  14091429  Panama Papers           NaN
# 4  10000089  registered_address  14098253  Panama Papers           NaN
#
#   r.start_date r.end_date
# 0          NaT        NaT
# 1          NaT        NaT
# 2          NaT        NaT
# 3          NaT        NaT
# 4          NaT        NaT

# %% [markdown]
# ## Some mining over morocco (draft)

# %%
#panama_edges[panama_edges['rel_type'] == 'intermediary_of' ]

# %%
morocco_nodes = panama_nodes[panama_nodes['n.countries']=='Morocco']
morocco_nodes.head(n=2)
# Out:
#         labels(n)                                   n.valid_until  \
# 21216  ["Entity"]  The Panama Papers data is current through 2015
# 23581  ["Entity"]  The Panama Papers data is current through 2015
#
#       n.country_codes n.countries  n.node_id     n.sourceID  \
# 21216             MAR     Morocco   10021401  Panama Papers
# 23581             MAR     Morocco   10023779  Panama Papers
#
#                                                n.address  \
# 21216  BASILEUS HOLDINGS OFFSHORE 183 AVENUE PRINCE H...
# 23581  BASILEUS HOLDINGS OFFSHORE 183 AVENUE PRINCE H...
#
#                                           n.name n.jurisdiction_description  \
# 21216                       VINTAGE FINANCE S.A.                 Seychelles
# 23581  ORANGEGREEN International Trading Limited                 Seychelles
#
#       n.service_provider n.jurisdiction  n.closed_date n.incorporation_date  \
# 21216    Mossack Fonseca            SEY            NaN           2008-03-12
# 23581    Mossack Fonseca            SEY            NaN           2009-01-20
#
#       n.ibcRUC  n.type n.status  n.company_type n.note
# 21216   046746     NaN   Active             NaN    NaN
# 23581   058193     NaN   Active             NaN    NaN

# %%
morocco_nodes[morocco_nodes['labels(n)']=='["Officer"]']['n.name'].unique()
# Out:
# array(['SAAD BEKKARI', 'Max Metral', 'VALLEY ELECTRIC HOLDING CORPORATION',
#        'JAMAL BENSSY', 'MRS. SIMONE ROUGE POITEVIN',
#        'BASILEUS HOLDING OFFSHORE SARL AU',
#        'BASILEUS HOLDING OFFSHORE SARL',
#        'Basileus Holding Offshore Sarl AU',
#        'BASILEUS HOLDINGS OFFSHORE SARL', 'FREDERICK MORELAND JR',
#        'Mr.Sandro Benati', 'Mr.David Houphouet-Boigny', 'CHARLES FLATHER',
#        'NIZAR  AL NAKEEB', 'KARIM DAMIR', 'VIRGINIA WOOSTER',
#        'Nizar Al-Nakeeb', 'MOISES LEVY', 'PANG YAN', 'TANG BIN',
#        'Mrs. Hiba Isam Wasef Jaber', 'Mrs. Mona Isam Wasef Jaber',
#        'Mrs. Farah Isam Wasef Jaber', 'Mrs. Maha Z. H. Alsaifi',
#        'Mr. Osama Isam Wasef Jaber', 'DAKIR BERRADA', 'SOFIA AMOR SAADANI',
#        'SOFIA SAADANI AMOR', 'MICHAEL E. BLOOM', 'QI DAFENG',
#        'Easil Land Ltd.', 'YAN LEBAU', 'CATHERINE GUEZ',
#        'JACQUELINE MATHIAS', 'SECURITIES HOUSE NOMINEES INC.',
#        'Omar Mouline', 'MRS. BEN-BRAHIM', 'MRS. ZINA NIZAR AL-NAKEEB',
#        'MRS ZINA NIZAR AL-NAKEEB', 'GHITA BENNIS', 'RITA BENNIS',
#        'Safa Al Khorsan', 'SAFA AL-KHORSAN', 'Mr. Jean-Pierre AMZALLAG',
#        'SAFA AL KHORSAN', 'Adil Jabrane', 'VALERIS PARRA', 'ANGEL PARRA',
#        'GÉRARD AMOUR ADOLPHE PARET', 'ATLANTIC RENTALS SDN BHD',
#        'PAUL SECONDY', 'ANDRE FERNAND MIKULOVIC', 'Jacqueline Mathias',
#        'Mr. Alexis KUPERFIS', 'Mounir Guessous',
#        'Mr. Abderrahim CHERKAOUI', 'Mrs. Leila Cherkaoui',
#        'Mr. Benjamin COHEN', 'Mrs. Ghita Bennis',
#        'Mr. Georgi Penev Kovachev'], dtype=object)

# %%
panama_nodes[panama_nodes['n.name']=='Mounir Majidi']
# Out:
#           labels(n)                                   n.valid_until  \
# 238394  ["Officer"]  The Panama Papers data is current through 2015
#
#        n.country_codes n.countries  n.node_id     n.sourceID n.address  \
# 238394             NaN         NaN   15006301  Panama Papers       NaN
#
#                n.name n.jurisdiction_description n.service_provider  \
# 238394  Mounir Majidi                        NaN                NaN
#
#        n.jurisdiction  n.closed_date n.incorporation_date n.ibcRUC  n.type  \
# 238394            NaN            NaN                  NaT      NaN     NaN
#
#        n.status  n.company_type                                       n.note
# 238394      NaN             NaN  Record manually added from leaked documents

# %% [markdown]
# # Evolution of the number of entities in France

# %%
france_nodes = panama_nodes[panama_nodes['n.countries']=='France']
france_year = pd.DataFrame(france_nodes['n.incorporation_date'].dropna().dt.year.astype(int).value_counts())
plt.figure(figsize=(10,5))
plt.plot(france_year['n.incorporation_date'].sort_index())
plt.xlabel('Year')
plt.ylabel('Number of entity')
plt.title('Number of Entities per year in france.')
plt.show()

print('Only {}% of the french data has an date'.format(np.sum(france_year['n.incorporation_date']) / france_nodes.shape[0]))
panama_year = pd.DataFrame(panama_entity['n.incorporation_date'].dropna().dt.year.astype(int).value_counts())
print('{}% of the data has an date'.format(np.sum(panama_year['n.incorporation_date']) / panama_entity.shape[0]))
# Out:
# Only 0.14675592173017507% of the french data has an date
# 0.999836168400161% of the data has an date

# %% [markdown]
# As we can see not enough data has an date to be consider a temproral analysis for France.

# %% [markdown]
# # Is there a correlation between the financial freedom and the number of entities coming from the same country in the dataset ?

# %% [markdown]
# To understand why entities are saving money in Panama, we gonna use this dataset: http://www.heritage.org/index.
# It contains differenct factors to determine how free a country is. We'll use the 2013 which is the oldest dataset on the webiste. It will represent the world status at this time before the leak. Our assumption here is that many accounts without date are recent accounts from the 2-4 previous year before the leak.

# %%
heritage_df = pd.read_excel('./Data/index2013_data.xls')
heritage_df.head()
# Out:
#    CountryID Country Name      WEBNAME                                 Region  \
# 0          1  Afghanistan  Afghanistan                           Asia-Pacific
# 1          2      Albania      Albania                                 Europe
# 2          3      Algeria      Algeria             Middle East / North Africa
# 3          4       Angola       Angola                     Sub-Saharan Africa
# 4          5    Argentina    Argentina  South and Central America / Caribbean
#
#    World Rank  Region Rank  2013 Score  Change in Yearly Score from 2012  \
# 0         NaN          NaN         NaN                               NaN
# 1        58.0         27.0        65.2                               0.1
# 2       145.0         14.0        49.6                              -1.4
# 3       158.0         40.0        47.3                               0.6
# 4       160.0         27.0        46.7                              -1.3
#
#    Property Rights  Change in Property Rights from 2012  \
# 0              NaN                                  NaN
# 1             30.0                                 -5.0
# 2             30.0                                  0.0
# 3             15.0                                 -5.0
# 4             15.0                                 -5.0
#
#             ...                Country  Population (Millions)  \
# 0           ...            Afghanistan                 31.084
# 1           ...                Albania                  3.218
# 2           ...                Algeria                 35.954
# 3           ...                 Angola                 19.625
# 4           ...              Argentina                 40.900
#
#    GDP (Billions, PPP)  GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# 0               29.731                5.737                   10.335398
# 1               24.910                2.000                    4.431419
# 2              263.661                2.470                    2.718594
# 3              115.679                3.404                    8.848807
# 4              716.419                8.870                    6.811779
#
#    GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# 0               956.448               NaN         11.247
# 1              7741.428              13.5          3.427
# 2              7333.226              10.0          4.500
# 3              5894.617               NaN         13.500
# 4             17516.147               7.2          9.775
#
#    FDI Inflow (Millions)  Public Debt (% of GDP)
# 0              83.411455                  12.100
# 1            1031.362818                  58.923
# 2            2571.000000                   9.925
# 3           -5585.529270                  30.897
# 4            7243.148181                  44.203
#
# [5 rows x 43 columns]
