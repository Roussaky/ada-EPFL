# %%
# Import libraries
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt

from collections import Counter
from bs4 import BeautifulSoup

# %%
BASE_URL = 'https://www.topuniversities.com'
# Make the request
r = requests.get('https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt?_=1508079297350')
json_result = r.json()

# %%
def getUniInfo(URL):
    #International faculty member

    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    #Extract the div with the intels about the faculty
    facultyDiv  = soup.find("div", class_="faculty-main wrapper col-md-4")
    
    #In the case the data is not on the page
    if facultyDiv is None:
        facultyInt = -1
        facultyTot = -1
    else:
        facultyInt = extract_number(facultyDiv.find("div", class_="inter faculty"))
        facultyTot = extract_number(facultyDiv.find("div", class_="total faculty"))
    
    #Extract the div with the intels about the student

    studentInt = soup.find("div", class_="total inter")
    studentTot = soup.find("div", class_="total student")
    #In the case the data is not on the page
    
    if studentInt is None:
        studentInt = -1
    else:
        studentInt = extract_number(studentInt)
        
    if studentTot is None:
        studentTot = -1
    else:
        studentTot = extract_number(studentTot)
        
    return facultyInt,facultyTot,studentInt,studentTot

def extract_number(t):
    #Answer on how to extract the int out of string found here:
    #https://stackoverflow.com/questions/26825729/extract-number-from-string-python
    
    #In case the faculty doesn't have international faculty member
    if t is None:
        return -1
    
    return int(''.join(filter(str.isdigit, t.find("div", class_="number").text)))

# %%
#Building the dataFrame
df = pd.DataFrame(columns = ['Rank','Name','Country','Region','FacultyMemberInt','FacultyMemberTot','StudentInt','StudentTot'])

nb = 0
for i in json_result.keys():
    for x in json_result[i]:
        
        if nb == 200:
            break
        
        #print(x['title'])
        nb = nb + 1
        facultyInt,facultyTot,studentInt,studentTot = getUniInfo(BASE_URL + x['url'])
        current_uni = [x['rank_display'],x['title'],x['country'],x['region'],facultyInt,facultyTot,studentInt,studentTot]
        df.loc[len(df)] = current_uni

# %%
df.tail()
# Out:
#      Rank                                               Name        Country  \
# 195  =195                  Universitat Autònoma de Barcelona          Spain
# 196  =195                               Texas A&M University  United States
# 197   199  Instituto Tecnológico y de Estudios Superiores...         Mexico
# 198   200                              Maastricht University    Netherlands
# 199   201                               Universidad de Chile          Chile
#
#             Region FacultyMemberInt FacultyMemberTot StudentInt StudentTot
# 195         Europe              230             2187       3848      31986
# 196  North America              206             3446       4900      60294
# 197  Latin America              821             1822       1412      13376
# 198         Europe              502             1277       8234      16385
# 199  Latin America              127             2256       2134      38848

# %%
def getBestRatio(data,col1,col2,Mode="MAXIMIZE"):
    """Compute and return the best ratio col1 / col2.FilteringBy indicate the column header we want to filter by"""
    if Mode == 'MAXIMIZE':
        bestRatio = 0
        bestName = ''
    elif Mode == 'MINIMIZE':
        bestRatio = 100
        bestName = ''
    else:
        return -1,"Mode should be MINIMIZE or MAXIMIZE"
    
    ratios = pd.DataFrame(columns = ['Name','Ratio'])
    for index, row in data.iterrows():

        currentRatio = row[col1] / row[col2]
        ratios.loc[len(ratios)] = [row['Name'],currentRatio]
        if Mode=="MAXIMIZE" and row[col1] > 0 and row[col2] > 0:
            if bestRatio < currentRatio:
                bestRatio = currentRatio
                bestName = row['Name']
        elif Mode=="MINIMIZE" and row[col1] > 0 and row[col2] > 0:
            if bestRatio > currentRatio:
                bestRatio = currentRatio
                bestName = row['Name']
                
    return bestName,bestRatio,ratios

def extract_number(t):
    #Answer on how to extract the int out of string found here:
    #https://stackoverflow.com/questions/26825729/extract-number-from-string-python
    
    #In case the faculty doesn't have international faculty member
    if t is None:
        return -1
    
    return int(''.join(filter(str.isdigit, t)))

# %%
#Get the best ratio of international faculty member.
uniWithBestFacRatio, maxIntFacRatio = getBestRatio(df,'StudentTot','FacultyMemberTot','MINIMIZE')
print("Best ratio between faculty members and students:\nName = {n}, Ratio = {r}".format(n=uniWithBestFacRatio,r=maxIntFacRatio))   

#Get the best ratio of international student.
uniWithBestStudRatio, maxIntStudRatio = getBestRatio(df,'StudentInt','StudentTot')
print("Best ratio of international student:\nName = {n}, Ratio = {r}".format(n=uniWithBestStudRatio,r=maxIntStudRatio))
# Out:
# Best ratio between faculty members and students:
# Name = California Institute of Technology (Caltech), Ratio = 2.366211962224554
# Best ratio of international student:
# Name = London School of Economics and Political Science (LSE), Ratio = 0.6913934426229508

# %%
#Get the list of the countries in the dataFrame
countryStats = pd.DataFrame(columns = ['Name','FacultyMemberInt','FacultyMemberTot','StudentInt','StudentTot'])
countries = df.Country.unique()

for country in countries:
    
    #Ignore the row with -1
    currentCountry = df[(df.Country == country)&(df.StudentInt >=0)&(df.StudentTot >=0)&(df.FacultyMemberInt >=0)&(df.FacultyMemberTot >=0)]
    
    #Sum the columns
    IntStud = currentCountry.StudentInt.sum()
    TotStud = currentCountry.StudentTot.sum()
    IntFac = currentCountry.FacultyMemberInt.sum()
    TotFac = currentCountry.FacultyMemberTot.sum()
    
    currentCountry = [country,IntFac,TotFac,IntStud,TotStud]
    countryStats.loc[len(countryStats)] = (currentCountry)
    
CountryWithBestFacRatio, maxIntFacCountryRatio = getBestRatio(countryStats,'FacultyMemberInt','FacultyMemberTot','MINIMIZE')
print("Best ratio between faculty members and students:\nName = {n}, Ratio = {r}".format(n=CountryWithBestFacRatio,r=maxIntFacCountryRatio)) 

CountryWithBestStudRatio, maxIntStudCountryRatio = getBestRatio(countryStats,'StudentInt','StudentTot')
print("Best ratio of international student:\nName = {n}, Ratio = {r}".format(n=CountryWithBestStudRatio,r=maxIntStudCountryRatio))
# Out:
# Best ratio between faculty members and students:
# Name = India, Ratio = 0.01713859910581222
# Best ratio of international student:
# Name = Australia, Ratio = 0.3521891163400597

# %%
#Get the list of the countries in the dataFrame
RegionStats = pd.DataFrame(columns = ['Name','FacultyMemberInt','FacultyMemberTot','StudentInt','StudentTot'])
regions = df.Region.unique()

for region in regions:
    
    #Delete the row with -1
    currentRegion = df[(df.Region == region)&(df.StudentInt >=0)&(df.StudentTot >=0)&(df.FacultyMemberInt >=0)&(df.FacultyMemberTot >=0)]
    
    #Sum the columns
    IntStud = currentRegion.StudentInt.sum()
    TotStud = currentRegion.StudentTot.sum()
    IntFac = currentRegion.FacultyMemberInt.sum()
    TotFac = currentRegion.FacultyMemberTot.sum()
    
    currentRegion = [region,IntFac,TotFac,IntStud,TotStud]
    RegionStats.loc[len(RegionStats)] = (currentRegion)
    
RegionWithBestFacRatio, maxIntFacRegionRatio = getBestRatio(RegionStats,'FacultyMemberTot','StudentTot','MINIMIZE')
print("Best ratio between faculty members and students:\nName = {n}, Ratio = {r}".format(n=RegionWithBestFacRatio,r=maxIntFacRegionRatio)) 

RegionWithBestStudRatio, maxIntStudRegionRatio = getBestRatio(RegionStats,'StudentInt','StudentTot')
print("Best ratio of international student:\nName = {n}, Ratio = {r}".format(n=RegionWithBestStudRatio,r=maxIntStudRegionRatio))
# Out:
# Best ratio between faculty members and students:
# Name = Oceania, Ratio = 0.07238546179394403
# Best ratio of international student:
# Name = Oceania, Ratio = 0.3392609811889755

# %% [markdown]
# ## Plotting the result of the first task

# %%
ratio = RegionStats['StudentInt']/RegionStats['StudentTot']

plt.hist(RegionStats['Name'],ratio)
plt.title('Ratio of international student for both ranking')
plt.xlabel('Region')
plt.ylabel('%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-5d97581a60c2> in <module>()
#       1 ratio = RegionStats['StudentInt']/RegionStats['StudentTot']
#       2
# ----> 3 plt.hist(RegionStats['Name'],ratio)
#       4 plt.title('Ratio of international student for both ranking')
#       5 plt.xlabel('Region')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3079                       histtype=histtype, align=align, orientation=orientation,
#    3080                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3081                       stacked=stacked, data=data, **kwargs)
#    3082     finally:
#    3083         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6193             # this will automatically overwrite bins,
#    6194             # so that each histogram uses the same bins
# -> 6195             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6196             m = m.astype(float)  # causes problems later if it's an int
#    6197             if mlast is None:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in histogram(a, bins, range, normed, weights, density)
#     660             mn, mx = 0.0, 1.0
#     661         else:
# --> 662             mn, mx = a.min() + 0.0, a.max() + 0.0
#     663     else:
#     664         mn, mx = [mi + 0.0 for mi in range]
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: cannot perform reduce with flexible type

# %%
RegionStats
# Out:
#             Name FacultyMemberInt FacultyMemberTot StudentInt StudentTot
# 0  North America            43836           182123     292116    1546353
# 1         Europe            67598           218358     449364    1957251
# 2           Asia            25462           106311     110053     802932
# 3        Oceania            12786            25347     118798     350167
# 4  Latin America             5648            45382      36871     435750
# 5         Africa              379             1733       3325      19593

# %% [markdown]
# ## Retreiving Data From timeshighereducation website:

# %%
API_URL_DATA = "https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json"#Building the dataFrame
json_result = requests.get(API_URL_DATA).json()["data"]
times_ranking = pd.DataFrame(columns = ['Rank','Name','Country','FacultyMemberTot','StudentInt','StudentTot'])
nb = 0
for x in json_result:        
    if nb == 200:
        break        
    studentTot = extract_number(x['stats_number_students']) 
    studentInt = int(extract_number(x['stats_pc_intl_students'])*studentTot/100)
    facultyTot = int(studentTot/float(x['stats_student_staff_ratio']))
    current_uni = [x['rank'],x['name'],x['location'],facultyTot,studentInt,studentTot]
    times_ranking.loc[nb] = current_uni
    nb = nb + 1

# %%
times_ranking.tail()
# Out:
#      Rank                                  Name         Country  \
# 195   196   Paris-Sorbonne University – Paris 4          France
# 196   197  Royal Holloway, University of London  United Kingdom
# 197  =198   University of California, Riverside   United States
# 198  =198              University of Gothenburg          Sweden
# 199  =198            National Taiwan University          Taiwan
#
#     FacultyMemberTot StudentInt StudentTot
# 195              729       3306      22042
# 196              579       3572       8931
# 197             1001       2903      20740
# 198             1837       2389      18378
# 199             2761       2540      31758

# %%
# a) Get the best ratio between faculty members and students,
uniWithBestRatio, maxRatio = getBestRatio(times_ranking,'StudentTot','FacultyMemberTot','MINIMIZE')
print("Best ratio between faculty members and students:\n  Name = {n}, Ratio 'number of students per staff' = {r}".format(n=uniWithBestRatio,r=maxRatio))   

# b) Get the best ratio of international student.
uniWithBestStudRatio, maxIntStudRatio = getBestRatio(times_ranking,'StudentInt','StudentTot')
print("Best ratio of international student:\n  Name = {n}, Ratio = {r}".format(n=uniWithBestStudRatio,r=maxIntStudRatio))
# Out:
# Best ratio between faculty members and students:
#   Name = Vanderbilt University, Ratio 'number of students per staff' = 3.300632041769717
# Best ratio of international student:
#   Name = London School of Economics and Political Science, Ratio = 0.7099850968703427

# %%
#Get the list of the countries in the dataFrame
countryStats = pd.DataFrame(columns = ['Name','FacultyMemberTot','StudentInt','StudentTot'])
countries = times_ranking.Country.unique()

for country in countries:
    
    #Delete the row with -1
    currentCountry = times_ranking[(times_ranking.Country == country)&(times_ranking.StudentInt >=0)&(times_ranking.StudentTot >=0)&(times_ranking.FacultyMemberTot >=0)]
    
    #Sum the columns
    IntStud = currentCountry.StudentInt.sum()
    TotStud = currentCountry.StudentTot.sum()
    TotFac = currentCountry.FacultyMemberTot.sum()
    
    currentCountry = [country,TotFac,IntStud,TotStud]
    countryStats.loc[len(countryStats)] = (currentCountry)

# a) Get the best ratio between faculty members and students by country
CountryWithBestFacRatio, maxIntFacCountryRatio = getBestRatio(countryStats,'StudentTot','FacultyMemberTot','MINIMIZE')
print("Best ratio between faculty members and students by country:\n  Name = {n}, Ratio 'number of students per staff' = {r}".format(n=CountryWithBestFacRatio,r=maxIntFacCountryRatio)) 

# b) Get the best ratio of international student by country
CountryWithBestStudRatio, maxIntStudCountryRatio = getBestRatio(countryStats,'StudentInt','StudentTot')
print("Best ratio of international student vy country:\n  Name = {n}, Ratio = {r}".format(n=CountryWithBestStudRatio,r=maxIntStudCountryRatio))
# Out:
# Best ratio between faculty members and students by country:
#   Name = Denmark, Ratio 'number of students per staff' = 6.05039637599094
# Best ratio of international student vy country:
#   Name = Luxembourg, Ratio = 0.5699335882471323

# %% [markdown]
# ## Merging

# %%
#names = df["Name"].values.tolist()
#x = [s for s in names if "(" in s]
for i in range(0,len(df)):
    test = df["Name"][i]
    if( test.find("(") != -1 and test.find(")") != -1):
        extract = test[test.find("(")+1:test.find(")")]
        if(2*len(extract) < len(test)):
            test = test.replace("("+extract+")","")  
        else:
            test = extract
    df["Name"][i]=test

# %%
df = df.set_index(['Name'])
times_ranking = times_ranking.set_index(["Name"])

# %%
import numpy as np
def f(row):
    cx = row["Country_x"]
    cy = row["Country_y"]
    if not pd.isnull(cy) :
        return cy
    return cx

# %%
merge = pd.merge(df,times_ranking,how="inner",left_index=True,right_index=True)
merge["Country"] = merge.apply(f, axis=1) 
merge.drop(["Country_x","Country_y","StudentInt_y","StudentTot_y","FacultyMemberTot_y"], axis=1, inplace=True) #drop country_x & country_y
merge.rename(columns={'Rank_x': 'Times_Ranking', 'Rank_y': 'TopU_Ranking','FacultyMemberTot_x':'FacultyMemberTot','StudentTot_x':'StudentTot','StudentInt_x':'StudentInt'}, inplace=True)

# %%
merge[["Times_Ranking","TopU_Ranking","Country","Region","FacultyMemberTot","FacultyMemberInt","StudentTot","StudentInt"]]
# Out:
#                                  Times_Ranking TopU_Ranking         Country  \
# Name
# Stanford University                          2           =3   United States
# Harvard University                           3            6   United States
# University of Cambridge                      5            2  United Kingdom
# University of Oxford                         6            1  United Kingdom
# University College London                    7           16  United Kingdom
# Imperial College London                      8            8  United Kingdom
# University of Chicago                        9            9   United States
# Princeton University                        13            7   United States
# Cornell University                          14           19   United States
# Yale University                             16           12   United States
# Johns Hopkins University                    17           13   United States
# Columbia University                         18           14   United States
# University of Pennsylvania                  19          =10   United States
# University of Michigan                     =21           21   United States
# Duke University                            =21           17   United States
# Tsinghua University                         25           30           China
# Northwestern University                    =28           20   United States
# University of Toronto                       31          =22          Canada
# McGill University                           32           42          Canada
# Kyoto University                           =36          =74           Japan
# Seoul National University                  =36          =74     South Korea
# Peking University                          =38          =27           China
# Fudan University                            40          116           China
# University of Bristol                       44           76  United Kingdom
# Carnegie Mellon University                 =47           24   United States
# City University of Hong Kong                49         =119       Hong Kong
# University of British Columbia              51          =34          Canada
# Brown University                            53          =50   United States
# Delft University of Technology              54           63     Netherlands
# University of Wisconsin-Madison             55           43   United States
# ...                                        ...          ...             ...
# Aalto University                          =137          190         Finland
# McMaster University                        140           78          Canada
# RWTH Aachen University                     141           79         Germany
# University of Pittsburgh                  =142         =100   United States
# University of Oslo                        =142          146          Norway
# University of Lausanne                     146          152     Switzerland
# Erasmus University Rotterdam              =147          =72     Netherlands
# Emory University                          =147           98   United States
# University of Basel                       =149          =95     Switzerland
# Michigan State University                 =149          =83   United States
# University of Vienna                       154         =165         Austria
# École Normale Supérieure de Lyon           157         =182          France
# University of Aberdeen                    =158          185  United Kingdom
# Newcastle University                      =161         =175  United Kingdom
# University of Minnesota                    163          =56   United States
# University of California, Irvine          =164           99   United States
# University of Bern                         167         =105     Switzerland
# Dartmouth College                          169           89   United States
# University of Liverpool                   =173         =177  United Kingdom
# University of Virginia                    =173         =113   United States
# University of Florida                      178         =143   United States
# University of Twente                      =179         =179     Netherlands
# University of Göttingen                    181         =113         Germany
# University of Colorado Boulder            =182         =100   United States
# University of Rochester                    186         =153   United States
# University of Cape Town                    191          171    South Africa
# Scuola Normale Superiore di Pisa          =192          184           Italy
# Stockholm University                      =195         =134          Sweden
# Texas A&M University                      =195         =159   United States
# Maastricht University                      200          103     Netherlands
#
#                                          Region FacultyMemberTot  \
# Name
# Stanford University               North America             4285
# Harvard University                North America             4350
# University of Cambridge                  Europe             5490
# University of Oxford                     Europe             6750
# University College London                Europe             6345
# Imperial College London                  Europe             3930
# University of Chicago             North America             2449
# Princeton University              North America             1007
# Cornell University                North America             2718
# Yale University                   North America             4940
# Johns Hopkins University          North America             4462
# Columbia University               North America             6189
# University of Pennsylvania        North America             5499
# University of Michigan            North America             6809
# Duke University                   North America             2938
# Tsinghua University                        Asia             5506
# Northwestern University           North America             4231
# University of Toronto             North America             9581
# McGill University                 North America             3646
# Kyoto University                           Asia             4060
# Seoul National University                  Asia             3930
# Peking University                          Asia             5185
# Fudan University                           Asia             4037
# University of Bristol                    Europe             2870
# Carnegie Mellon University        North America             1342
# City University of Hong Kong               Asia             1349
# University of British Columbia    North America             4648
# Brown University                  North America             1303
# Delft University of Technology           Europe             1669
# University of Wisconsin-Madison   North America             5722
# ...                                         ...              ...
# Aalto University                         Europe             1257
# McMaster University               North America             3231
# RWTH Aachen University                   Europe             3176
# University of Pittsburgh          North America             4982
# University of Oslo                       Europe             2509
# University of Lausanne                   Europe             2173
# Erasmus University Rotterdam             Europe             2011
# Emory University                  North America             2560
# University of Basel                      Europe             1057
# Michigan State University         North America             2884
# University of Vienna                     Europe             3411
# École Normale Supérieure de Lyon         Europe              382
# University of Aberdeen                   Europe             1310
# Newcastle University                     Europe             2428
# University of Minnesota           North America             4919
# University of California, Irvine  North America             1926
# University of Bern                       Europe             1172
# Dartmouth College                 North America              939
# University of Liverpool                  Europe             2390
# University of Virginia            North America             2509
# University of Florida             North America             5419
# University of Twente                     Europe              910
# University of Göttingen                  Europe             3678
# University of Colorado Boulder    North America             3685
# University of Rochester           North America             2569
# University of Cape Town                  Africa             1733
# Scuola Normale Superiore di Pisa         Europe               86
# Stockholm University                     Europe             2154
# Texas A&M University              North America             3446
# Maastricht University                    Europe             1277
#
#                                  FacultyMemberInt StudentTot StudentInt
# Name
# Stanford University                          2042      15878       3611
# Harvard University                           1311      22429       5266
# University of Cambridge                      2278      18770       6699
# University of Oxford                         2964      19720       7353
# University College London                    2554      31080      14854
# Imperial College London                      2071      16090       8746
# University of Chicago                         635      13557       3379
# Princeton University                          246       8069       1793
# Cornell University                            970      21904       5411
# Yale University                              1708      12402       2469
# Johns Hopkins University                     1061      16146       4105
# Columbia University                           913      25045       8105
# University of Pennsylvania                   1383      20639       4250
# University of Michigan                       1920      43147       7527
# Duke University                               226      15320       2864
# Tsinghua University                           932      36300       4072
# Northwestern University                      1141      18675       3422
# University of Toronto                        3905      72207      21910
# McGill University                            1220      28837       9540
# Kyoto University                              293      22974       1990
# Seoul National University                     433      28064       2331
# Peking University                            1038      42136       7090
# Fudan University                             1178      29135       4680
# University of Bristol                         942      20630       5099
# Carnegie Mellon University                    425      13356       6385
# City University of Hong Kong                 1027       9240       3273
# University of British Columbia               1635      50350      11388
# Brown University                              379       9251       1825
# Delft University of Technology                701      16527       4634
# University of Wisconsin-Madison              1151      38985       4920
# ...                                           ...        ...        ...
# Aalto University                              370      12147       1831
# McMaster University                          1170      23702       3548
# RWTH Aachen University                        449      44517       8556
# University of Pittsburgh                      572      26393       2937
# University of Oslo                            711      24304       3667
# University of Lausanne                       1031      13435       3337
# Erasmus University Rotterdam                  458      23273       5229
# Emory University                              484      12852       2154
# University of Basel                           684      12852       3441
# Michigan State University                     653      44951       7427
# University of Vienna                         1400      45967      14468
# École Normale Supérieure de Lyon               91       2020        221
# University of Aberdeen                        508      12005       4246
# Newcastle University                          835      21673       5717
# University of Minnesota                       195      59742       6542
# University of California, Irvine              377      32151       8538
# University of Bern                            661      10758       1618
# Dartmouth College                              27       6224        945
# University of Liverpool                       717      22065       7502
# University of Virginia                        487      21560       1899
# University of Florida                         504      45485       4597
# University of Twente                          299       9332       2235
# University of Göttingen                       641      30402       3736
# University of Colorado Boulder                566      30219       2679
# University of Rochester                       488       9636       2805
# University of Cape Town                       379      19593       3325
# Scuola Normale Superiore di Pisa                1        532         48
# Stockholm University                          646      28281       2636
# Texas A&M University                          206      60294       4900
# Maastricht University                         502      16385       8234
#
# [105 rows x 8 columns]

# %%
#Searching a correlation between the international dimension and the ranking
data = pd.DataFrame(columns = ['Times_Ranking','TopU_Ranking','InternationalStudRatio','InternationalFacRatio'])

for index, row in merge.iterrows():
    current_rank_times = row['Times_Ranking']
    if '=' in current_rank_times[:1]:
        current_rank_times = current_rank_times[1:]
        
    current_rank_U = row['TopU_Ranking']
    if '=' in current_rank_U[:1]:
        current_rank_U = current_rank_U[1:]
    
    current_stud_ratio = row['StudentInt'] / row['StudentTot']
    current_fac_ratio = row['FacultyMemberInt'] / row['FacultyMemberTot']
    current_row = [current_rank_times,current_rank_U,current_stud_ratio,current_fac_ratio]
    data.loc[len(data)] = current_row
    
plt.plot(data['Times_Ranking'],data['InternationalStudRatio'],'.',data['TopU_Ranking'],data['InternationalStudRatio'],'r.')
plt.axis([0, 200, 0, 1])
plt.title('Ratio of international student for both ranking')
plt.xlabel('Ranking')
plt.legend(["Times ranking","TopU Ranking"])
plt.ylabel('%')
plt.show()

plt.plot(data['Times_Ranking'],data['InternationalStudRatio'] - data['InternationalFacRatio'],'.')
plt.axis([0, 200, -0.2, 0.2])
plt.title('Differences between ratio of international student and international faculty member')
plt.xlabel('Times ranking')
plt.ylabel('%')
plt.show()
