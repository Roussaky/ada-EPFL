# %%
# Import libraries
import requests
import pandas as pd
import json

from bs4 import BeautifulSoup

# %%
# Make the request
r = requests.get('https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt?_=1508079297350')
json_result = r.json()

# %%
#Building the dataFrame
df = pd.DataFrame(columns = ['Rank','Name','Country','Region'])#,'FacultyMemberInt','FacultyMemberTot','StudentInt','StudentTot'])

nb = 0
for i in json_result.keys():
    for x in json_result[i]:
        
        if nb == 200:
            break
        
        nb = nb + 1
        current_uni = [x['rank_display'],x['title'],x['country'],x['region']]
        df.loc[len(df)]= current_uni
        

display(df)
# Out:
#      Rank                                               Name         Country  \
# 0       1        Massachusetts Institute of Technology (MIT)   United States
# 1       2                                Stanford University   United States
# 2       3                                 Harvard University   United States
# 3       4       California Institute of Technology (Caltech)   United States
# 4       5                            University of Cambridge  United Kingdom
# 5       6                               University of Oxford  United Kingdom
# 6       7                    UCL (University College London)  United Kingdom
# 7       8                            Imperial College London  United Kingdom
# 8       9                              University of Chicago   United States
# 9      10  ETH Zurich - Swiss Federal Institute of Techno...     Switzerland
# 10     11  Nanyang Technological University, Singapore (NTU)       Singapore
# 11     12    Ecole Polytechnique Fédérale de Lausanne (EPFL)     Switzerland
# 12     13                               Princeton University   United States
# 13     14                                 Cornell University   United States
# 14     15             National University of Singapore (NUS)       Singapore
# 15     16                                    Yale University   United States
# 16     17                           Johns Hopkins University   United States
# 17     18                                Columbia University   United States
# 18     19                         University of Pennsylvania   United States
# 19     20                 The Australian National University       Australia
# 20    =21                                    Duke University   United States
# 21    =21                             University of Michigan   United States
# 22    =23                              King's College London  United Kingdom
# 23    =23                        The University of Edinburgh  United Kingdom
# 24     25                                Tsinghua University           China
# 25     26                        The University of Hong Kong       Hong Kong
# 26     27           University of California, Berkeley (UCB)   United States
# 27    =28                            Northwestern University   United States
# 28    =28                            The University of Tokyo           Japan
# 29     30  The Hong Kong University of Science and Techno...       Hong Kong
# ..    ...                                                ...             ...
# 170   171               Albert-Ludwigs-Universitaet Freiburg         Germany
# 171   172        Indian Institute of Technology Delhi (IITD)           India
# 172  =173                             University of Virginia   United States
# 173  =173       King Fahd University of Petroleum & Minerals    Saudi Arabia
# 174  =173                            University of Liverpool  United Kingdom
# 175   176                    University of Technology Sydney       Australia
# 176   177                                    CentraleSupélec          France
# 177   178                              University of Florida   United States
# 178  =179                               University of Twente     Netherlands
# 179  =179       Indian Institute of Technology Bombay (IITB)           India
# 180   181                            University of Göttingen         Germany
# 181  =182                   Vrije Universiteit Brussel (VUB)         Belgium
# 182  =182        Universidade Estadual de Campinas (Unicamp)          Brazil
# 183  =182                     University of Colorado Boulder   United States
# 184  =182                    Vienna University of Technology         Austria
# 185   186                            University of Rochester   United States
# 186   187                     Universidad Autónoma de Madrid           Spain
# 187  =188       Alma Mater Studiorum - University of Bologna           Italy
# 188  =188                              University of Reading  United Kingdom
# 189   190       Indian Institute of Science (IISc) Bangalore           India
# 190   191                            University of Cape Town    South Africa
# 191  =192                           Keio University CEMS MIM           Japan
# 192  =192                   Scuola Normale Superiore di Pisa           Italy
# 193  =192  Scuola Superiore Sant'Anna Pisa di Studi Unive...           Italy
# 194  =195                               Texas A&M University   United States
# 195  =195                               Stockholm University          Sweden
# 196  =195                  Universitat Autònoma de Barcelona           Spain
# 197   199  Instituto Tecnológico y de Estudios Superiores...          Mexico
# 198   200                              Maastricht University     Netherlands
# 199   201                               Universidad de Chile           Chile
#
#             Region
# 0    North America
# 1    North America
# 2    North America
# 3    North America
# 4           Europe
# 5           Europe
# 6           Europe
# 7           Europe
# 8    North America
# 9           Europe
# 10            Asia
# 11          Europe
# 12   North America
# 13   North America
# 14            Asia
# 15   North America
# 16   North America
# 17   North America
# 18   North America
# 19         Oceania
# 20   North America
# 21   North America
# 22          Europe
# 23          Europe
# 24            Asia
# 25            Asia
# 26   North America
# 27   North America
# 28            Asia
# 29            Asia
# ..             ...
# 170         Europe
# 171           Asia
# 172  North America
# 173           Asia
# 174         Europe
# 175        Oceania
# 176         Europe
# 177  North America
# 178         Europe
# 179           Asia
# 180         Europe
# 181         Europe
# 182  Latin America
# 183  North America
# 184         Europe
# 185  North America
# 186         Europe
# 187         Europe
# 188         Europe
# 189           Asia
# 190         Africa
# 191           Asia
# 192         Europe
# 193         Europe
# 194  North America
# 195         Europe
# 196         Europe
# 197  Latin America
# 198         Europe
# 199  Latin America
#
# [200 rows x 4 columns]

# %%
r = requests.get('https://www.topuniversities.com/universities/massachusetts-institute-technology-mit#wurs')
